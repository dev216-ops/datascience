# %%
import pandas as pd

# %%
# @hidden_cell
# The project token is an authorization token that is used to access project resources like data sources, connections, and used by platform APIs.
from project_lib import Project
project = Project(project_id='cb053384-0316-4672-ba60-986adc0639a6', project_access_token='p-485a115893e5824664120012b2c6b34e140de362')
pc = project.project_context

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_9155f035bbb848f090df21b21b39ec74 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='rDn5OLM8gzYbWbKT0YVLCzShZf6V23XaPn_nETsvpy4v',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_9155f035bbb848f090df21b21b39ec74.get_object(Bucket='measlesoutbreakanalysis-donotdelete-pr-hvsh11jd2sje52',Key='NY Measle Breakdown.xlsx')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )
usecols=['Neighborhood', 'Confirmed Cases']

df_data_0 = pd.read_excel(body)
df_data_0.head(25)
# Out:
#     Zip Code                       Neighborhood  Confirmed Cases
# 0      11204                        Bensonhurst                3
# 1      11219                      Borough Park               123
# 2      11235        Brighton Beach/Coney Island                5
# 3      11205                    Chelsea/Clinton                1
# 4      11225                      Crown Heights                8
# 5      11691                       Far Rockaway                1
# 6      11226                           Flatbush                1
# 7      11355                           Flushing                3
# 8      10474  Hunts Point, Longwood and Melrose                1
# 9      11236                           Jamaica                 2
# 10     11101           Long Island City/Astoria                1
# 11     11230                Midwood/Marine Park                5
# 12     10302                      Port Richmond                3
# ...

# %%
# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_9155f035bbb848f090df21b21b39ec74 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='rDn5OLM8gzYbWbKT0YVLCzShZf6V23XaPn_nETsvpy4v',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')
body = client_9155f035bbb848f090df21b21b39ec74.get_object(Bucket='measlesoutbreakanalysis-donotdelete-pr-hvsh11jd2sje52',Key='state data.xlsx')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_0 = pd.read_excel(body)
df_data_0.head(50)
# Out:
#           State          County  Measle Cases
# 0   Connecticut       New Haven             3
# 1       Georgia           Fulton            7
# 2      Maryland       Balitmore             5
# 3      Michigan          Oakland           38
# 4      Michigan            Wayne            1
# 5    New Jersey           Ocean             7
# 6    New Jersey          Bergen             1
# 7    New Jersey            Essex            1
# 8    New Jersey        Monmouth             2
# 9     New York          Rockland           11
# 10    New York             Kings           40
# 11       Oregon        Clackamas            6
# 12       Oregon           Marion            9
# 13       Oregon        Vancouver            9
# 14  Washington            Clark            55
# 15   California         ​Alameda           ​1
# 16   California     ​Los Angeles           21
# 17   California          ​Orange            7
# 18   California          ​Placer            5
# ...

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
 
# Fake dataset
height = [3, 5, 7, 9, 9, 22, 24, 51, 55, 79]
bars = ('CT', 'MD', 'GA', 'NJ', 'IL', 'TX', 'OR', 'NY', 'WA', 'CA')

y_pos = np.arange(len(bars))
 
# Create bars and choose color
plt.bar(y_pos, height, color = (0.5,0.1,0.5,0.6))
 
# Add title and axis names
plt.title('2018 Measles State Data')
plt.xlabel('States')
plt.ylabel('Confirmed Cases')
 
# Limits for the Y axis
plt.ylim(0,100)
 
# Create names
plt.xticks(y_pos, bars)
 
# Show graphic
plt.show()

# %%
body = client_9155f035bbb848f090df21b21b39ec74.get_object(Bucket='measlesoutbreakanalysis-donotdelete-pr-hvsh11jd2sje52',Key='US Measles.xlsx')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_0 = pd.read_excel(body)
df_data_0.head(15)
# Out:
#      Month   Measle Cases
# 0  January             127
# 1  February            125
# 2     March            303
# 3     April            341
# 4      May             181
# 5      June             77
# 6     July              50
# 7    August             24

# %%
body = client_9155f035bbb848f090df21b21b39ec74.get_object(Bucket='measlesoutbreakanalysis-donotdelete-pr-hvsh11jd2sje52',Key='coverage_estimates_series.xls')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

# If you are reading an Excel file into a pandas DataFrame, replace `read_csv` by `read_excel` in the next statement.
df_data_0 = pd.read_excel(body)
df_data_0.head()
# Out:
#                           Country Vaccine  2018  2017  2016  2015  2014  2013  \
# 0  United States of America (the)    MCV1  0.92  0.92  0.92  0.92  0.92  0.92
# 1  United States of America (the)    MCV2  0.94  0.94  0.94  0.93  0.92  0.91
#
#    2012  2011  ...  2009  2008  2007  2006  2005  2004  2003  2002  2001  2000
# 0  0.91  0.92  ...  0.90  0.92  0.92  0.92  0.92  0.93  0.93  0.91  0.91  0.91
# 1  0.91  0.90  ...  0.88  0.87  0.86  0.86  0.86  0.86  0.86  0.86  0.86  0.85
#
# [2 rows x 21 columns]

# %%
import matplotlib.pyplot as plt 
import numpy as np
import matplotlib.ticker as ticker
fig, ax = plt.subplots()

x = np.array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018])
y1 = np.array([91, 91, 91, 93, 93, 92, 92, 92, 92, 90, 92,92, 91, 92, 92, 92, 92, 92, 92])
y2= np.array([85, 86, 86, 86, 86, 86, 86, 87, 88, 89, 90,91, 91, 92, 93, 94, 94, 94, 94])

# plotting the line 1 points  
plt.plot(x1, y1, label = "MMR1") 
  
# plotting the line 2 points  
plt.plot(x1, y2, label = "MMR2") 
  
# naming the x axis 
plt.xlabel('Year') 
# naming the y axis 
plt.ylabel('Percent') 
# giving a title to my graph 
plt.title('10 Year Breakdown of MMR Dosing') 
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
    
ax.margins(0.05)
ax.axis('tight')
fig.tight_layout()
  
# show a legend on the plot 
plt.legend() 
  
# function to show the plot 
plt.show()

# %%
body = client_9155f035bbb848f090df21b21b39ec74.get_object(Bucket='measlesoutbreakanalysis-donotdelete-pr-hvsh11jd2sje52',Key='New Measle Cases.xlsx')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_0 = pd.read_excel(body)
df_data_0.head(20)
# Out:
#     Year WHO Region  Total Suspected  Total measles  Clinically confirmed  \
# 0   2018        AFR          85195.0          55394                 14242
# 1   2018        AMR              NaN          16689                     0
# 2   2018        EMR          83332.0          57960                 29432
# 3   2018        EUR          99208.0          84462                 50975
# 4   2018       SEAR         111545.0          83647                 58143
# 5   2018        WPR          80204.0          30531                 18254
# 6   2019        AFR         192277.0         177542                 23524
# 7   2019        AMR              NaN           2387                     0
# 8   2019        EMR          28852.0          15917                  9952
# 9   2019        EUR          98308.0          90012                 53888
# 10  2019       SEAR          53439.0          35778                 25293
# 11  2019        WPR         110498.0          43175                 35266
#
# ...
